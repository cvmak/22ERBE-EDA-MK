# %%
import pandas as pd

# %%
df=pd.read_csv('eplusout.csv')
df
# Out:
#              Date/Time  \
# 0      12/21  01:00:00
# 1      12/21  02:00:00
# 2      12/21  03:00:00
# 3      12/21  04:00:00
# 4      12/21  05:00:00
# ...                ...
# 8803   12/31  20:00:00
# 8804   12/31  21:00:00
# 8805   12/31  22:00:00
# 8806   12/31  23:00:00
# 8807   12/31  24:00:00
#
#       Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)  \
# 0                                              -15.5000
# 1                                              -15.5000
# 2                                              -15.5000
# 3                                              -15.5000
# 4                                              -15.5000
# ...                                                 ...
# 8803                                            13.1125
# 8804                                            12.6125
# 8805                                            11.2000
# 8806                                            10.6000
# ...
